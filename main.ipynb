# %%
# %load_ext autoreload
# %autoreload 2
import os
from pathlib import Path
from IPython.display import display

from scholar_scraper import *

# %%
# get you Scholar id from your page
# (e.g., https://scholar.google.com/citations?user=73-D2jgAAAAJ)
author_id = "73-D2jgAAAAJ"

# register on https://serpapi.com/ and get your SerpApi key
os.environ["SERP_API_KEY"] = "<YOUR_KEY>"

# cache your results
out_path = Path("results")

# depending on the number of your citations, scraping might:
# 1. require a paid serpapi plan
# 2. take a while (~ 7 sec/citation)...
results = scrape_author(author_id, out_path=out_path)
# Out:
# Articles:   0%|          | 0/22 [00:00<?, ?it/s]

# %%
# load results as pandas dataframe
author_path = out_path / author_id
results = load_yaml(author_path / "results.yaml")
df = get_citation_df(results, keep_warnings=True)
df.sort_values("article").head(3)
# Out:
#               name                                       affiliations  \
# 158   Simon Welker                                Universität Hamburg
# 111  Yoshua Bengio  Professor of computer science, University of M...
# 113  Maxence Noble         Ph.D. Student, Ecole Polytechnique, France
#
#                                    email                          website  \
# 158      Verified email at unihamburg.de                              NaN
# 111       Verified email at umontreal.ca        https://yoshuabengio.org/
# 113  Verified email at polytechnique.edu  https://maxencenoble.github.io/
#
#           email_domain warnings affil_country              affil_name  \
# 158      unihamburg.de       []            DE     Universität Hamburg
# 111       umontreal.ca       []            CA  Université de Montréal
# 113  polytechnique.edu       []            FR     Ecole Polytechnique
#
#      citations abbrv_name                                            article  \
# 158      287.0   S Welker  An optimal control perspective on diffusion-ba...
# 111   799012.0   Y Bengio  An optimal control perspective on diffusion-ba...
# 113       81.0    M Noble  An optimal control perspective on diffusion-ba...
#
#                     article_id  \
# 158  73-D2jgAAAAJ:W7OEmFMy1HYC
# 111  73-D2jgAAAAJ:W7OEmFMy1HYC
# 113  73-D2jgAAAAJ:W7OEmFMy1HYC
#
#                                               citation           citation_id  \
# 158  DriftRec: Adapting diffusion models to blind J...                  None
# 111  On diffusion models for amortized inference: B...  15947547171699022423
# 113  Stochastic Localization via Iterative Posterio...  17344046561291018738
#
#         author_id affil_country_name
# 158  If3qsuwAAAAJ            Germany
# 111  kukA0LcAAAAJ             Canada
# 113  4eGHx3gAAAAJ             France

# %%
# authors that most often cited your articles
cols = ["name", "cited_by_name", "affil_name", "website"]
author_df = drop_and_count_duplicates(
    df, ["name", "author_id"], col_name="cited_by_name"
)
author_df.loc[:, cols].sort_values("cited_by_name", ascending=False).head(5)
# Out:
#                 name  cited_by_name  \
# 1858   philipp grohs           37.0
# 2099  Arnulf Jentzen           31.0
# 57     Julius Berner           25.0
# 1877  Gitta Kutyniok           20.0
# 56    Lorenz Richter           20.0
#
#                                      affil_name  \
# 1858                         Universität Vienna
# 2099  Westfälische Wilhelms-Universität Münster
# 57           California Institute of Technology
# 1877     Ludwig-Maximilians-Universität München
# 56                        Zuse Institute Berlin
#
#                                website
# 1858          http://mds.univie.ac.at/
# 2099           http://www.ajentzen.de/
# 57               https://jberner.info/
# 1877  http://www.math.lmu.de/~kutyniok
# 56                                 NaN

# %%
# citing authors with most citations
cols = ["name", "citations", "affil_name", "website"]
author_df.loc[:, cols].sort_values("citations", ascending=False).head(10)
# Out:
#                        name  citations                             affil_name  \
# 63            Yoshua Bengio   798537.0                 Université de Montréal
# 68              Kevin Black   263059.0      University of Wisconsin - Madison
# 62          Aaron Courville   248850.0                 Université de Montréal
# 1751           Philip S. Yu   198809.0      University of Illinois at Chicago
# 223         Sepp Hochreiter   155041.0       Johannes Kepler Universität Linz
# 2076            Dacheng Tao   124900.0       Nanyang Technological University
# 320     Joshua B. Tenenbaum   110169.0  Massachusetts Institute of Technology
# 1549     Seyedali Mirjalili   109722.0                    Griffith University
# 1300  George Em Karniadakis   106354.0                       Brown University
# 578      Michael Wooldridge    85143.0                   University of Oxford
#
#                                                 website
# 63                            https://yoshuabengio.org/
# 68    https://www.physics.wisc.edu/directory/black-k...
# 62                 http://aaroncourville.wordpress.com/
# 1751                         http://www.cs.uic.edu/PSYu
# 223   https://www.jku.at/en/institute-for-machine-le...
# 2076                                                NaN
# 320                http://web.mit.edu/cocosci/josh.html
# 1549                     https://seyedalimirjalili.com/
# 1300  https://www.brown.edu/research/projects/crunch...
# 578   http://www.cs.ox.ac.uk/people/michael.wooldridge/

# %%
# map of citing authors
get_map(author_df, out_path=author_path, radius_scale=5, radius_log_base=2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4019e66f9f2b8985f6f0f1374d0d5ba0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4019e66f9f2b8985f6f0f1374d0d5ba0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4019e66f9f2b8985f6f0f1374d0d5ba0 = L.map(
#                 &quot;map_4019e66f9f2b8985f6f0f1374d0d5ba0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5a836c2d2f7694662661fdac0743814 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e5a836c2d2f7694662661fdac0743814.addTo(map_4019e66f9f2b8985f6f0f1374d0d5ba0);
#
#
#             var circle_marker_5ee08cf8d00b1f752490b0bb083b6893 = L.circleMarker(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 44.9858974046881, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_4019e66f9f2b8985f6f0f1374d0d5ba0);
#
#
#             circle_marker_5ee08cf8d00b1f752490b0bb083b6893.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;US&lt;/b&gt;: 511
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_40b3403de4cfa07bfbe02be6772cbb4d = L.circleMarker(
#                 [35.000074, 104.999927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 37.53897320099348, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_4019e66f9f2b8985f6f0f1374d0d5ba0);
#
#
#             circle_marker_40b3403de4cfa07bfbe02be6772cbb4d.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CN&lt;/b&gt;: 182
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b37bd3f64df52c93500eea63c7e21341 = L.circleMarker(
#                 [51.1638175, 10.4478313],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 33.50219859070546, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_4019e66f9f2b8985f6f0f1374d0d5ba0);
#
#
#             circle_marker_b37bd3f64df52c93500eea63c7e21341.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;DE&lt;/b&gt;: 104
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_fac26ca05ddfd0f3106caa14b4882dd0 = L.circleMarker(
#                 [54.7023545, -3.2765753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 33.36212670985748, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_4019e66f9f2b8985f6f0f1374d0d5ba0);
#
#
#             circle_marker_fac26ca05ddfd0f3106caa14b4882dd0.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;GB&lt;/b&gt;: 102
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_4cdc51125c5c7d1bfe610dfc9ed51288 = L.circleMarker(
#                 [61.0666922, -107.991707],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null,

# %%
# affiliations that most often cited your articles
cols = ["affil_name", "cited_by_affil", "affil_country_name"]
affil_df = drop_and_count_duplicates(df, ["affil_name"], col_name="cited_by_affil")
affil_df.loc[:, cols].sort_values("cited_by_affil", ascending=False).head(5)
# Out:
#                                          affil_name  cited_by_affil  \
# 289                              Universität Vienna            66.0
# 19    Swiss Federal Institute of Technology, Zurich            56.0
# 3                California Institute of Technology            46.0
# 1131      Westfälische Wilhelms-Universität Münster            40.0
# 311                                       Microsoft            38.0
#
#      affil_country_name
# 289             Austria
# 19          Switzerland
# 3         United States
# 1131            Germany
# 311       United States

# %%
# affiliations citing specific articles
cols = ["citations", "affil_name", "affil_country_name", "cited_by_affil"]
for article in df.loc[:, "article"].unique():
    print(article)
    article_df = df.loc[df.loc[:, "article"] == article].dropna(subset=["affil_name"])
    article_df = article_df.sort_values("citations", ascending=False)
    article_df = drop_and_count_duplicates(
        article_df, ["affil_name"], col_name="cited_by_affil"
    )
    display(article_df.loc[:, cols].head(5))
# Out:
# Pretraining Codomain Attention Neural Operators for Solving Multiphysics PDEs
#    citations                          affil_name affil_country_name  \
# 6    27728.0  California Institute of Technology      United States
# 2     2705.0          Frostburg State University      United States
#
#    cited_by_affil
# 6               3
# 2               3
# DPOT: Auto-Regressive Denoising Operator Transformer for Large-Scale PDE Pre-Training
#     citations                                     affil_name  \
# 16    46964.0                     University of Pennsylvania
# 11    36042.0                            Tsinghua University
# 24     9640.0  Swiss Federal Institute of Technology, Zurich
#
#    affil_country_name  cited_by_affil
# 16      United States               5
# 11              China               4
# 24        Switzerland               5
# Neural Operators with Localized Integral and Differential Kernels
#     citations                                         affil_name  \
# 33    46964.0                         University of Pennsylvania
# 37    17926.0  Bayerische Julius-Maximilians-Universität Würz...
# 28     9966.0                                             NVIDIA
# 27     4890.0                 California Institute of Technology
#
#    affil_country_name  cited_by_affil
# 33      United States               5
# 37            Germany               3
# 28      United States               1
# 27      United States               3
# An optimal control perspective on diffusion-based generative modeling
#      citations                                     affil_name  \
# 111   799012.0                         Université de Montréal
# 68    263059.0              University of Wisconsin - Madison
# 136    63989.0                           University of Oxford
# 142    30073.0  Swiss Federal Institute of Technology, Zurich
# 60     11077.0                                           Meta
#
#     affil_country_name  cited_by_affil
# 111             Canada              10
# 68       United States               1
# 136     United Kingdom               5
# 142        Switzerland               7
# 60       United States               2
# Improved sampling via learned diffusions
#      citations                        affil_name affil_country_name  \
# 213   799012.0            Université de Montréal             Canada
# 223   155041.0  Johannes Kepler Universität Linz            Austria
# 248    63989.0              University of Oxford     United Kingdom
# 183    11077.0                              Meta      United States
# 237     5399.0               Stanford University      United States
#
#      cited_by_affil
# 213              12
# 223               2
# 248               5
# 183               1
# 237               1
# Mathematical Capabilities of ChatGPT
#       citations                             affil_name affil_country_name  \
# 1751   198809.0      University of Illinois at Chicago      United States
# 320    110169.0  Massachusetts Institute of Technology      United States
# 1549   109722.0                    Griffith University          Australia
# 1300   106354.0                       Brown University      United States
# 578     85143.0                   University of Oxford     United Kingdom
#
#       cited_by_affil
# 1751               2
# 320                8
# 1549               1
# 1300               4
# 578               14
# Large Language Models for Mathematicians
#       citations             affil_name affil_country_name  cited_by_affil
# 1834     8913.0   University of Oxford     United Kingdom               1
# 1827     7075.0                   Meta      United States               1
# 1833     4377.0  Ohio State University      United States               4
# 1828      724.0  University of Toronto             Canada               3
# 1825      276.0     Nanjing University              China               2
# Physics-Informed Neural Operators with Exact Differentiation on Arbitrary Geometries
#       citations                        affil_name affil_country_name  \
# 1843    20743.0               Stanford University      United States
# 1841    19578.0  University of California, Irvine      United States
# 1838    11096.0     University of Texas at Austin      United States
# 1846       29.0                            NVIDIA      United States
#
#       cited_by_affil
# 1843               4
# 1841               2
# 1838               3
# 1846               1
# Learning ReLU networks to high uniform accuracy is intractable
#       citations                          affil_name affil_country_name  \
# 1850     8366.0                Texas A&M University      United States
# 1853     7950.0       Claremont Graduate University      United States
# 1851     4994.0  California Institute of Technology      United States
# 1864     3993.0                  Universität Vienna            Austria
# 1856     1739.0                   Peking University              China
#
#       cited_by_affil
# 1850               4
# 1853               1
# 1851               1
# 1864               4
# 1856               1
# The Modern Mathematics of Deep Learning
#       citations                        affil_name affil_country_name  \
# 2076   124900.0  Nanyang Technological University          Singapore
# 1988    45237.0           University of Cambridge     United Kingdom
# 2045    44881.0        King Abdul Aziz University       Saudi Arabia
# 2068    44479.0               Columbia University      United States
# 1896    43958.0       Technische Universität Graz            Austria
#
#       cited_by_affil
# 2076               1
# 1988               8
# 2045               2
# 2068               1
# 1896               3
# Robust SDE-Based Variational Formulations for Solving Linear PDEs via Deep Learning
#       citations                           affil_name affil_country_name  \
# 2378    30713.0   California Institute of Technology      United States
# 2373     9966.0                               NVIDIA      United States
# 2396     9422.0     University of California, Merced      United States
# 2388     3993.0                   Universität Vienna            Austria
# 2420     1909.0  University of Minnesota - Crookston      United States
#
#       cited_by_affil
# 2378               7
# 2373               2
# 2396               1
# 2388               1
# 2420               1
# Group testing for SARS-CoV-2 allows for up to 10-fold efficiency increase across realistic scenarios and testing strategies
#       citations                                 affil_name affil_country_name  \
# 2461    46020.0                         Harvard University      United States
# 2525    28210.0  State University of New York at New Paltz      United States
# 2512    14128.0          University of Wisconsin - Madison      United States
# 2493    13717.0                    Simon Fraser University             Canada
# 2579    13716.0      University of California, Los Angeles      United States
#
#       cited_by_affil
# 2461               4
# 2525               1
# 2512               1
# 2493               5
# 2579              17
# Numerically Solving Parametric Families of High-Dimensional Kolmogorov Partial Differential Equations via Deep Learning
#       citations                          affil_name affil_country_name  \
# 2724    80799.0   University of Wisconsin - Madison      United States
# 2692    63344.0                           Microsoft      United States
# 2720    33347.0       University of South Australia          Australia
# 2655    30713.0  California Institute of Technology      United States
# 2643    28394.0          University of Pennsylvania      United States
#
#       cited_by_affil
# 2724               3
# 2692               9
# 2720               2
# 2655               7
# 2643               1
# Analysis of the Generalization Error: Empirical Risk Minimization over Deep Artificial Neural Networks Overcomes the Curse of Dimensionality in the Numerical Approximation of …
#       citations                                     affil_name  \
# 3027   106354.0                               Brown University
# 3051    33347.0                  University of South Australia
# 3034    26183.0                           Princeton University
# 3041    24534.0  Swiss Federal Institute of Technology, Zurich
# 2935    24373.0                               Universität Graz
#
#      affil_country_name  cited_by_affil
# 3027      United States               1
# 3051          Australia               3
# 3034      United States               5
# 3041        Switzerland              28
# 2935            Austria               2
# Towards a regularity theory for ReLU networks–chain rule and global error estimates
#       citations                                 affil_name affil_country_name  \
# 3348    60996.0                      University of Florida      United States
# 3378    59082.0                        Stanford University      United States
# 3329    10503.0  Westfälische Wilhelms-Universität Münster            Germany
# 3350     8220.0                Humboldt Universität Berlin            Germany
# 3334     3993.0                         Universität Vienna            Austria
#
#       cited_by_affil
# 3348               7
# 3378               1
# 3329               1
# 3350               2
# 3334               4
# How degenerate is the parametrization of neural networks with the ReLU activation function?
#       citations                               affil_name affil_country_name  \
# 3435    45144.0                   University of Manitoba             Canada
# 3446    19980.0      Institute of Science and Technology            Austria
# 3463    19169.0  Faculty of Engineering, Lund University             Sweden
# 3459    18182.0   Ludwig-Maximilians-Universität München            Germany
# 3458    15776.0           Technische Universität München            Germany
#
#       cited_by_affil
# 3435               1
# 3446               1
# 3463               2
# 3459               3
# 3458               1
